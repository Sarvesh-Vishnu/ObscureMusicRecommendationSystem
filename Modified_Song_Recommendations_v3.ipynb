# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
Spotify_Client_ID = '3f171623fda2487bb16422c30f7983e6'
Spotify_Client_Secret = 'd88bbd8e8b8a4b12b8896ef7d775375f'

# %%
auth_manager = SpotifyClientCredentials(client_id = Spotify_Client_ID, client_secret = Spotify_Client_Secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# ## Searching Tracks

# %%
results = sp.search(q='track:'+'mudhal',type='track')

# %%
def filter_unpopular_songs(results, popularity_threshold=30):
    """Filter tracks with popularity below the given threshold."""
    filtered_tracks = []
    for track in results['tracks']['items']:
        if track['popularity'] < popularity_threshold:
            filtered_tracks.append(track)
    return filtered_tracks

# %%
def get_genre_tracks(genres, sp_client, num_tracks=5):
    """Get tracks from different genres."""
    genre_tracks = {}
    for genre in genres:
        results = sp_client.search(q='genre:' + genre, type='track', limit=num_tracks)
        genre_tracks[genre] = results['tracks']['items']
    return genre_tracks

# %%
def recommend_language_tracks(sp_client, languages, num_tracks=5):
    """Recommend tracks in different languages. Placeholder function."""
    # Implementing language-based recommendations would require additional data
    # or a method to infer language from track or artist metadata.
    pass

# %%
results['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=track%3Amudhal&type=track&offset=0&limit=10',
#  'items': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3r6JhF3T7IkDvhWWJSux9y'},
#     'href': 'https://api.spotify.com/v1/albums/3r6JhF3T7IkDvhWWJSux9y',
#     'id': '3r6JhF3T7IkDvhWWJSux9y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273adef0c80a6a250a62abc2890',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02adef0c80a6a250a62abc2890',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851adef0c80a6a250a62abc2890',
#       'width': 64}],
#     'name': 'Mudhal Nee Mudivum Nee (Original Motion Picture Soundtrack)',
#     'release_date': '2021-02-26',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:3r6JhF3T7IkDvhWWJSux9y'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#      'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#      'id': '7qjJw7ZM2ekDSahLXPjIlN',
#      'name': 'Sid Sriram',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 332702,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172002791'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4oNVmnywnXguyk76wkMuIb'},
#    'href': 'https://api.spotify.com/v1/tracks/4oNVmnywnXguyk76wkMuIb',
#    'id': '4oNVmnywnXguyk76wkMuIb',
#    'is_local': False,
#    'name': 'Mudhal Nee Mudivum Nee Title Track',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/641e705f8e37bb5d20c4d8698307ebd9083f80b9?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4oNVmnywnXguyk76wkMuIb'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#       'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#       'id': '29aw5YCdIw2FEXYyAJZI8l',
#       'name': 'Harris Jayaraj',
#       'type': 'artist',
#       'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3nIoedJvrwDRlR0QsRu8aL'},
#     'href': 'https://api.spotify.com/v1/albums/3nIoedJvrwDRlR0QsRu8aL',
#     'id': '3nIoedJvrwDRlR0QsRu8aL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737d570c876fbc113f1bd7bfd4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027d570c876fbc113f1bd7bfd4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517d570c876fbc113f1bd7bfd4',
#       'width': 64}],
#     'name': 'Vettaiyaadu Vilaiyaadu (Original Motion Picture Soundtrack)',
#     'release_date': '2006-03-08',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:3nIoedJvrwDRlR0QsRu8aL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#      'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#      'id': '29aw5YCdIw2FEXYyAJZI8l',
#      'name': 'Harris Jayaraj',
#      'type': 'artist',
#      'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EYD74wB45dOQXt27hh144'},
#      'href': 'https://api.spotify.com/v1/artists/1EYD74wB45dOQXt27hh144',
#      'id': '1EYD74wB45dOQXt27hh144',
#      'name': 'Unni Menon',
#      'type': 'artist',
#      'uri': 'spotify:artist:1EYD74wB45dOQXt27hh144'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5OTt6O4Q22YsqZDaWV6FqC'},
#      'href': 'https://api.spotify.com/v1/artists/5OTt6O4Q22YsqZDaWV6FqC',
#      'id': '5OTt6O4Q22YsqZDaWV6FqC',
#      'name': 'Bombay Jayashri',
#      'type': 'artist',
#      'uri': 'spotify:artist:5OTt6O4Q22YsqZDaWV6FqC'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 366040,
#    'explicit': False,
#    'external_ids': {'isrc': 'IND292205884'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/03GldviaGI7cvpCBuuyrrP'},
#    'href': 'https://api.spotify.com/v1/tracks/03GldviaGI7cvpCBuuyrrP',
#    'id': '03GldviaGI7cvpCBuuyrrP',
#    'is_local': False,
#    'name': 'Paartha Mudhal',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fcb55ecd963ae80d7ccd09a380ee3e39bfdbd3cc?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:03GldviaGI7cvpCBuuyrrP'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3hDQpJsEBtu5cIXUtC8ykc'},
#     'href': 'https://api.spotify.com/v1/albums/3hDQpJsEBtu5cIXUtC8ykc',
#     'id': '3hDQpJsEBtu5cIXUtC8ykc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27353d2e893acf43d05c2ffa216',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0253d2e893acf43d05c2ffa216',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485153d2e893acf43d05c2ffa216',
#       'width': 64}],
#     'name': 'Mudhal Nee Mudivum Nee Title Track (From "Mudhal Nee Mudivum Nee")',
#     'release_date': '2020-09-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3hDQpJsEBtu5cIXUtC8ykc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#      'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#      'id': '7qjJw7ZM2ekDSahLXPjIlN',
#      'name': 'Sid Sriram',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 332702,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172002791'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1AzNN19lPYC68iacrbWL8X'},
#    'href': 'https://api.spotify.com/v1/tracks/1AzNN19lPYC68iacrbWL8X',
#    'id': '1AzNN19lPYC68iacrbWL8X',
#    'is_local': False,
#    'name': 'Mudhal Nee Mudivum Nee Title Track (From "Mudhal Nee Mudivum Nee")',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/037a50b4c59a6c1835ee3e03fdbc2e2bac27069d?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1AzNN19lPYC68iacrbWL8X'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#       'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#       'id': '1SJOL9HJ08YOn92lFcYf8a',
#       'name': 'Shankar Mahadevan',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7t4REBeDRM21rNDhvd1fZ7'},
#     'href': 'https://api.spotify.com/v1/albums/7t4REBeDRM21rNDhvd1fZ7',
#     'id': '7t4REBeDRM21rNDhvd1fZ7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b67db713bde6c152991694eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b67db713bde6c152991694eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b67db713bde6c152991694eb',
#       'width': 64}],
#     'name': 'Hits of Shankar Mahadevan',
#     'release_date': '2013-03-25',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7t4REBeDRM21rNDhvd1fZ7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#      'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#      'id': '1SJOL9HJ08YOn92lFcYf8a',
#      'name': 'Shankar Mahadevan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HGMG8RHvcu1mfdM9MeTek'},
#      'href': 'https://api.spotify.com/v1/artists/1HGMG8RHvcu1mfdM9MeTek',
#      'id': '1HGMG8RHvcu1mfdM9MeTek',
#      'name': 'Sadhana Sargam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HGMG8RHvcu1mfdM9MeTek'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 307720,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS280500612'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1DfsxoKqz6M6CSOkX8HpxR'},
#    'href': 'https://api.spotify.com/v1/tracks/1DfsxoKqz6M6CSOkX8HpxR',
#    'id': '1DfsxoKqz6M6CSOkX8HpxR',
#    'is_local': False,
#    'name': 'Merke Merke ( From" Kanda Naal Mudhalai")',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e9df5bd00b259fc380d3726a532aea6d334d26ec?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:1DfsxoKqz6M6CSOkX8HpxR'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#       'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#       'id': '29aw5YCdIw2FEXYyAJZI8l',
#       'name': 'Harris Jayaraj',
#       'type': 'artist',
#       'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7Jx7jUDz94Lz1giBbruPvz'},
#     'href': 'https://api.spotify.com/v1/albums/7Jx7jUDz94Lz1giBbruPvz',
#     'id': '7Jx7jUDz94Lz1giBbruPvz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d2fc343ffc64e2a432c4833',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d2fc343ffc64e2a432c4833',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d2fc343ffc64e2a432c4833',
#       'width': 64}],
#     'name': 'Lesa Lesa (Original Motion Picture Soundtrack)',
#     'release_date': '2003-05-16',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:7Jx7jUDz94Lz1giBbruPvz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#      'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#      'id': '29aw5YCdIw2FEXYyAJZI8l',
#      'name': 'Harris Jayaraj',
#      'type': 'artist',
#      'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/61if35zz1W11GejEkxTLEQ'},
#      'href': 'https://api.spotify.com/v1/artists/61if35zz1W11GejEkxTLEQ',
#      'id': '61if35zz1W11GejEkxTLEQ',
#      'name': 'Benny Dayal',
#      'type': 'artist',
#      'uri': 'spotify:artist:61if35zz1W11GejEkxTLEQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/01FTzx4XnS1JHNp5rPlkMk'},
#      'href': 'https://api.spotify.com/v1/artists/01FTzx4XnS1JHNp5rPlkMk',
#      'id': '01FTzx4XnS1JHNp5rPlkMk',
#      'name': 'Yugendran',
#      'type': 'artist',
#      'uri': 'spotify:artist:01FTzx4XnS1JHNp5rPlkMk'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QrOW5VVKkMPUWFYGTR4kB'},
#      'href': 'https://api.spotify.com/v1/artists/6QrOW5VVKkMPUWFYGTR4kB',
#      'id': '6QrOW5VVKkMPUWFYGTR4kB',
#      'name': 'Srimathumitha',
#      'type': 'artist',
#      'uri': 'spotify:artist:6QrOW5VVKkMPUWFYGTR4kB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0PykiHCcDsMPRV7s67qZ1B'},
#      'href': 'https://api.spotify.com/v1/artists/0PykiHCcDsMPRV7s67qZ1B',
#      'id': '0PykiHCcDsMPRV7s67qZ1B',
#      'name': 'Tippu',
#      'type': 'artist',
#      'uri': 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 329013,
#    'explicit': False,
#    'external_ids': {'isrc': 'IND291600731'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/79B67CygqqtpaahPalGdgl'},
#    'href': 'https://api.spotify.com/v1/tracks/79B67CygqqtpaahPalGdgl',
#    'id': '79B67CygqqtpaahPalGdgl',
#    'is_local': False,
#    'name': 'Mudhal Mudhalai',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/66bbd9fb169940330b6f284978d04c324d27667b?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:79B67CygqqtpaahPalGdgl'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NoJ7NuNs9nyj8Thoh1kbu'},
#       'href': 'https://api.spotify.com/v1/artists/2NoJ7NuNs9nyj8Thoh1kbu',
#       'id': '2NoJ7NuNs9nyj8Thoh1kbu',
#       'name': 'Hariharan',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wPsNCwhEGb0KvChZ5DD52'},
#       'href': 'https://api.spotify.com/v1/artists/2wPsNCwhEGb0KvChZ5DD52',
#       'id': '2wPsNCwhEGb0KvChZ5DD52',
#       'name': 'K. J. Yesudas',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wPsNCwhEGb0KvChZ5DD52'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1kzbFZiILCf520UCCPOhvz'},
#     'href': 'https://api.spotify.com/v1/albums/1kzbFZiILCf520UCCPOhvz',
#     'id': '1kzbFZiILCf520UCCPOhvz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d6f63aefe2221a24e7043827',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d6f63aefe2221a24e7043827',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d6f63aefe2221a24e7043827',
#       'width': 64}],
#     'name': 'Singer Special Hariharan and K.J.Jesudas',
#     'release_date': '2013-05-13',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:1kzbFZiILCf520UCCPOhvz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NoJ7NuNs9nyj8Thoh1kbu'},
#      'href': 'https://api.spotify.com/v1/artists/2NoJ7NuNs9nyj8Thoh1kbu',
#      'id': '2NoJ7NuNs9nyj8Thoh1kbu',
#      'name': 'Hariharan',
#      'type': 'artist',
#      'uri': 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Yb0T3wUUNiIvHjqnfkbuH'},
#      'href': 'https://api.spotify.com/v1/artists/0Yb0T3wUUNiIvHjqnfkbuH',
#      'id': '0Yb0T3wUUNiIvHjqnfkbuH',
#      'name': 'Mahalakshmi Iyer',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Yb0T3wUUNiIvHjqnfkbuH'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 398341,
#    'explicit': False,
#    'external_ids': {'isrc': 'INF049900244'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/00QuXoF6LyKwH9xz7lXGdf'},
#    'href': 'https://api.spotify.com/v1/tracks/00QuXoF6LyKwH9xz7lXGdf',
#    'id': '00QuXoF6LyKwH9xz7lXGdf',
#    'is_local': False,
#    'name': 'Kurukku Siruthvalea (From Mudhalvan)',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0113caa84116a413852a7fb9e10dd92443c33829?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:00QuXoF6LyKwH9xz7lXGdf'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3m49WVMU4zCkaVEKb8kFW7'},
#       'href': 'https://api.spotify.com/v1/artists/3m49WVMU4zCkaVEKb8kFW7',
#       'id': '3m49WVMU4zCkaVEKb8kFW7',
#       'name': 'Ilaiyaraaja',
#       'type': 'artist',
#       'uri': 'spotify:artist:3m49WVMU4zCkaVEKb8kFW7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6tzoyTXujURrI4cP3qddow'},
#     'href': 'https://api.spotify.com/v1/albums/6tzoyTXujURrI4cP3qddow',
#     'id': '6tzoyTXujURrI4cP3qddow',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736eb2962bda91af6ed29ee8ff',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026eb2962bda91af6ed29ee8ff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516eb2962bda91af6ed29ee8ff',
#       'width': 64}],
#     'name': 'Neethaane En Ponvasantham (Original Motion Picture Soundtrack)',
#     'release_date': '2012-09-01',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:6tzoyTXujURrI4cP3qddow'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3m49WVMU4zCkaVEKb8kFW7'},
#      'href': 'https://api.spotify.com/v1/artists/3m49WVMU4zCkaVEKb8kFW7',
#      'id': '3m49WVMU4zCkaVEKb8kFW7',
#      'name': 'Ilaiyaraaja',
#      'type': 'artist',
#      'uri': 'spotify:artist:3m49WVMU4zCkaVEKb8kFW7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3eDT9fwXKuHWFvgZaaYC5v'},
#      'href': 'https://api.spotify.com/v1/artists/3eDT9fwXKuHWFvgZaaYC5v',
#      'id': '3eDT9fwXKuHWFvgZaaYC5v',
#      'name': 'Sunidhi Chauhan',
#      'type': 'artist',
#      'uri': 'spotify:artist:3eDT9fwXKuHWFvgZaaYC5v'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 235733,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS171200447'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3re0HrBkLNV2lfHoTtSOgy'},
#    'href': 'https://api.spotify.com/v1/tracks/3re0HrBkLNV2lfHoTtSOgy',
#    'id': '3re0HrBkLNV2lfHoTtSOgy',
#    'is_local': False,
#    'name': 'Mudhal Murai',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2bff6dfd6abbd5bd2ec46a7b4ae42041a84b998e?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3re0HrBkLNV2lfHoTtSOgy'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Xpg6PBSUOoho2lI9qLjiu'},
#       'href': 'https://api.spotify.com/v1/artists/5Xpg6PBSUOoho2lI9qLjiu',
#       'id': '5Xpg6PBSUOoho2lI9qLjiu',
#       'name': 'S. Janaki',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Xpg6PBSUOoho2lI9qLjiu'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
# ...
#      'uri': 'spotify:artist:5Xpg6PBSUOoho2lI9qLjiu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#      'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#      'id': '1SJOL9HJ08YOn92lFcYf8a',
#      'name': 'Shankar Mahadevan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 392045,
#    'explicit': False,
#    'external_ids': {'isrc': 'INF049900245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3nhzRO4RPgq71kTlBah68A'},
#    'href': 'https://api.spotify.com/v1/tracks/3nhzRO4RPgq71kTlBah68A',
#    'id': '3nhzRO4RPgq71kTlBah68A',
#    'is_local': False,
#    'name': 'Mudhalvanae ( From "Mudhalvan")',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/093f9122109a9db1a915be9723aa385757299aa9?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3nhzRO4RPgq71kTlBah68A'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#       'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#       'id': '1SJOL9HJ08YOn92lFcYf8a',
#       'name': 'Shankar Mahadevan',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5t4ZtKPDT4r1ZPobRGIAyo'},
#     'href': 'https://api.spotify.com/v1/albums/5t4ZtKPDT4r1ZPobRGIAyo',
#     'id': '5t4ZtKPDT4r1ZPobRGIAyo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f52ac029b4974b9958fea06b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f52ac029b4974b9958fea06b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f52ac029b4974b9958fea06b',
#       'width': 64}],
#     'name': 'Hits of Shankar Mahadevan',
#     'release_date': '2013-05-29',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:5t4ZtKPDT4r1ZPobRGIAyo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#      'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#      'id': '1SJOL9HJ08YOn92lFcYf8a',
#      'name': 'Shankar Mahadevan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WPmTGeeoymoVlXVtsCwz7'},
#      'href': 'https://api.spotify.com/v1/artists/6WPmTGeeoymoVlXVtsCwz7',
#      'id': '6WPmTGeeoymoVlXVtsCwz7',
#      'name': 'Kavita Krishnamurthy',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WPmTGeeoymoVlXVtsCwz7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 334733,
#    'explicit': False,
#    'external_ids': {'isrc': 'INF049900246'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3qkoComBwdqR8ybOGo0jkw'},
#    'href': 'https://api.spotify.com/v1/tracks/3qkoComBwdqR8ybOGo0jkw',
#    'id': '3qkoComBwdqR8ybOGo0jkw',
#    'is_local': False,
#    'name': 'Uppu Karuvaadu ( From "Mudhalvan")',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8d105c14d68528b86756adac346f466e943972ff?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3qkoComBwdqR8ybOGo0jkw'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#       'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#       'id': '2ae6PxICSOZHvjqiCcgon8',
#       'name': 'S. P. Balasubrahmanyam',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wPsNCwhEGb0KvChZ5DD52'},
#       'href': 'https://api.spotify.com/v1/artists/2wPsNCwhEGb0KvChZ5DD52',
#       'id': '2wPsNCwhEGb0KvChZ5DD52',
#       'name': 'K. J. Yesudas',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wPsNCwhEGb0KvChZ5DD52'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2PtLTb5NE474dbmwT8d9nL'},
#     'href': 'https://api.spotify.com/v1/albums/2PtLTb5NE474dbmwT8d9nL',
#     'id': '2PtLTb5NE474dbmwT8d9nL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27331aa5dd8aa2a5b9c0ab1d362',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0231aa5dd8aa2a5b9c0ab1d362',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485131aa5dd8aa2a5b9c0ab1d362',
#       'width': 64}],
#     'name': 'S.P.B and K.J.Jesudas Hits',
#     'release_date': '2013-05-10',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:2PtLTb5NE474dbmwT8d9nL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#      'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#      'id': '2ae6PxICSOZHvjqiCcgon8',
#      'name': 'S. P. Balasubrahmanyam',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/41BeeC5hYqvtGkM79RYvN4'},
#      'href': 'https://api.spotify.com/v1/artists/41BeeC5hYqvtGkM79RYvN4',
#      'id': '41BeeC5hYqvtGkM79RYvN4',
#      'name': 'Harini',
#      'type': 'artist',
#      'uri': 'spotify:artist:41BeeC5hYqvtGkM79RYvN4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 367203,
#    'explicit': False,
#    'external_ids': {'isrc': 'INF049900247'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6GBn7HwE7SBqVKzdCPeheI'},
#    'href': 'https://api.spotify.com/v1/tracks/6GBn7HwE7SBqVKzdCPeheI',
#    'id': '6GBn7HwE7SBqVKzdCPeheI',
#    'is_local': False,
#    'name': 'Azhagana Rakshasiyea (From Mudhalvan)',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/341115a2a4d521bbe5696fbd2f374ddf7beda545?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6GBn7HwE7SBqVKzdCPeheI'}],
#  'limit': 10,
#  'next': 'https://api.spotify.com/v1/search?query=track%3Amudhal&type=track&offset=10&limit=10',
#  'offset': 0,
#  'previous': None,
#  'total': 603}

# %%
print(len(results['tracks']))
# Out:
# 7

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3r6JhF3T7IkDvhWWJSux9y'},
#    'href': 'https://api.spotify.com/v1/albums/3r6JhF3T7IkDvhWWJSux9y',
#    'id': '3r6JhF3T7IkDvhWWJSux9y',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273adef0c80a6a250a62abc2890',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02adef0c80a6a250a62abc2890',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851adef0c80a6a250a62abc2890',
#      'width': 64}],
#    'name': 'Mudhal Nee Mudivum Nee (Original Motion Picture Soundtrack)',
#    'release_date': '2021-02-26',
#    'release_date_precision': 'day',
#    'total_tracks': 5,
#    'type': 'album',
#    'uri': 'spotify:album:3r6JhF3T7IkDvhWWJSux9y'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#     'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#     'id': '5t97rjifUl8d4HNwSzbCv9',
#     'name': 'Darbuka Siva',
#     'type': 'artist',
#     'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#     'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#     'id': '7qjJw7ZM2ekDSahLXPjIlN',
#     'name': 'Sid Sriram',
#     'type': 'artist',
#     'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 332702,
#   'explicit': False,
#   'external_ids': {'isrc': 'INS172002791'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4oNVmnywnXguyk76wkMuIb'},
#   'href': 'https://api.spotify.com/v1/tracks/4oNVmnywnXguyk76wkMuIb',
#   'id': '4oNVmnywnXguyk76wkMuIb',
#   'is_local': False,
#   'name': 'Mudhal Nee Mudivum Nee Title Track',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/641e705f8e37bb5d20c4d8698307ebd9083f80b9?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4oNVmnywnXguyk76wkMuIb'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#      'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#      'id': '29aw5YCdIw2FEXYyAJZI8l',
#      'name': 'Harris Jayaraj',
#      'type': 'artist',
#      'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3nIoedJvrwDRlR0QsRu8aL'},
#    'href': 'https://api.spotify.com/v1/albums/3nIoedJvrwDRlR0QsRu8aL',
#    'id': '3nIoedJvrwDRlR0QsRu8aL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737d570c876fbc113f1bd7bfd4',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027d570c876fbc113f1bd7bfd4',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517d570c876fbc113f1bd7bfd4',
#      'width': 64}],
#    'name': 'Vettaiyaadu Vilaiyaadu (Original Motion Picture Soundtrack)',
#    'release_date': '2006-03-08',
#    'release_date_precision': 'day',
#    'total_tracks': 5,
#    'type': 'album',
#    'uri': 'spotify:album:3nIoedJvrwDRlR0QsRu8aL'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#     'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#     'id': '29aw5YCdIw2FEXYyAJZI8l',
#     'name': 'Harris Jayaraj',
#     'type': 'artist',
#     'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EYD74wB45dOQXt27hh144'},
#     'href': 'https://api.spotify.com/v1/artists/1EYD74wB45dOQXt27hh144',
#     'id': '1EYD74wB45dOQXt27hh144',
#     'name': 'Unni Menon',
#     'type': 'artist',
#     'uri': 'spotify:artist:1EYD74wB45dOQXt27hh144'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5OTt6O4Q22YsqZDaWV6FqC'},
#     'href': 'https://api.spotify.com/v1/artists/5OTt6O4Q22YsqZDaWV6FqC',
#     'id': '5OTt6O4Q22YsqZDaWV6FqC',
#     'name': 'Bombay Jayashri',
#     'type': 'artist',
#     'uri': 'spotify:artist:5OTt6O4Q22YsqZDaWV6FqC'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 366040,
#   'explicit': False,
#   'external_ids': {'isrc': 'IND292205884'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/03GldviaGI7cvpCBuuyrrP'},
#   'href': 'https://api.spotify.com/v1/tracks/03GldviaGI7cvpCBuuyrrP',
#   'id': '03GldviaGI7cvpCBuuyrrP',
#   'is_local': False,
#   'name': 'Paartha Mudhal',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fcb55ecd963ae80d7ccd09a380ee3e39bfdbd3cc?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:03GldviaGI7cvpCBuuyrrP'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3hDQpJsEBtu5cIXUtC8ykc'},
#    'href': 'https://api.spotify.com/v1/albums/3hDQpJsEBtu5cIXUtC8ykc',
#    'id': '3hDQpJsEBtu5cIXUtC8ykc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27353d2e893acf43d05c2ffa216',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0253d2e893acf43d05c2ffa216',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485153d2e893acf43d05c2ffa216',
#      'width': 64}],
#    'name': 'Mudhal Nee Mudivum Nee Title Track (From "Mudhal Nee Mudivum Nee")',
#    'release_date': '2020-09-02',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3hDQpJsEBtu5cIXUtC8ykc'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#     'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#     'id': '5t97rjifUl8d4HNwSzbCv9',
#     'name': 'Darbuka Siva',
#     'type': 'artist',
#     'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7qjJw7ZM2ekDSahLXPjIlN'},
#     'href': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#     'id': '7qjJw7ZM2ekDSahLXPjIlN',
#     'name': 'Sid Sriram',
#     'type': 'artist',
#     'uri': 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 332702,
#   'explicit': False,
#   'external_ids': {'isrc': 'INS172002791'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1AzNN19lPYC68iacrbWL8X'},
#   'href': 'https://api.spotify.com/v1/tracks/1AzNN19lPYC68iacrbWL8X',
#   'id': '1AzNN19lPYC68iacrbWL8X',
#   'is_local': False,
#   'name': 'Mudhal Nee Mudivum Nee Title Track (From "Mudhal Nee Mudivum Nee")',
#   'popularity': 68,
#   'preview_url': 'https://p.scdn.co/mp3-preview/037a50b4c59a6c1835ee3e03fdbc2e2bac27069d?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1AzNN19lPYC68iacrbWL8X'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#      'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#      'id': '1SJOL9HJ08YOn92lFcYf8a',
#      'name': 'Shankar Mahadevan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7t4REBeDRM21rNDhvd1fZ7'},
#    'href': 'https://api.spotify.com/v1/albums/7t4REBeDRM21rNDhvd1fZ7',
#    'id': '7t4REBeDRM21rNDhvd1fZ7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b67db713bde6c152991694eb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b67db713bde6c152991694eb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b67db713bde6c152991694eb',
#      'width': 64}],
#    'name': 'Hits of Shankar Mahadevan',
#    'release_date': '2013-03-25',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:7t4REBeDRM21rNDhvd1fZ7'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#     'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#     'id': '1SJOL9HJ08YOn92lFcYf8a',
#     'name': 'Shankar Mahadevan',
#     'type': 'artist',
#     'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HGMG8RHvcu1mfdM9MeTek'},
#     'href': 'https://api.spotify.com/v1/artists/1HGMG8RHvcu1mfdM9MeTek',
#     'id': '1HGMG8RHvcu1mfdM9MeTek',
#     'name': 'Sadhana Sargam',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HGMG8RHvcu1mfdM9MeTek'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 307720,
#   'explicit': False,
#   'external_ids': {'isrc': 'INS280500612'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1DfsxoKqz6M6CSOkX8HpxR'},
#   'href': 'https://api.spotify.com/v1/tracks/1DfsxoKqz6M6CSOkX8HpxR',
#   'id': '1DfsxoKqz6M6CSOkX8HpxR',
#   'is_local': False,
#   'name': 'Merke Merke ( From" Kanda Naal Mudhalai")',
#   'popularity': 62,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e9df5bd00b259fc380d3726a532aea6d334d26ec?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:1DfsxoKqz6M6CSOkX8HpxR'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#      'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#      'id': '29aw5YCdIw2FEXYyAJZI8l',
#      'name': 'Harris Jayaraj',
#      'type': 'artist',
#      'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7Jx7jUDz94Lz1giBbruPvz'},
#    'href': 'https://api.spotify.com/v1/albums/7Jx7jUDz94Lz1giBbruPvz',
#    'id': '7Jx7jUDz94Lz1giBbruPvz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734d2fc343ffc64e2a432c4833',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024d2fc343ffc64e2a432c4833',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514d2fc343ffc64e2a432c4833',
#      'width': 64}],
#    'name': 'Lesa Lesa (Original Motion Picture Soundtrack)',
#    'release_date': '2003-05-16',
#    'release_date_precision': 'day',
#    'total_tracks': 6,
#    'type': 'album',
#    'uri': 'spotify:album:7Jx7jUDz94Lz1giBbruPvz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29aw5YCdIw2FEXYyAJZI8l'},
#     'href': 'https://api.spotify.com/v1/artists/29aw5YCdIw2FEXYyAJZI8l',
#     'id': '29aw5YCdIw2FEXYyAJZI8l',
#     'name': 'Harris Jayaraj',
#     'type': 'artist',
#     'uri': 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/61if35zz1W11GejEkxTLEQ'},
#     'href': 'https://api.spotify.com/v1/artists/61if35zz1W11GejEkxTLEQ',
#     'id': '61if35zz1W11GejEkxTLEQ',
#     'name': 'Benny Dayal',
#     'type': 'artist',
#     'uri': 'spotify:artist:61if35zz1W11GejEkxTLEQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/01FTzx4XnS1JHNp5rPlkMk'},
#     'href': 'https://api.spotify.com/v1/artists/01FTzx4XnS1JHNp5rPlkMk',
#     'id': '01FTzx4XnS1JHNp5rPlkMk',
#     'name': 'Yugendran',
#     'type': 'artist',
#     'uri': 'spotify:artist:01FTzx4XnS1JHNp5rPlkMk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QrOW5VVKkMPUWFYGTR4kB'},
#     'href': 'https://api.spotify.com/v1/artists/6QrOW5VVKkMPUWFYGTR4kB',
#     'id': '6QrOW5VVKkMPUWFYGTR4kB',
#     'name': 'Srimathumitha',
#     'type': 'artist',
#     'uri': 'spotify:artist:6QrOW5VVKkMPUWFYGTR4kB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0PykiHCcDsMPRV7s67qZ1B'},
#     'href': 'https://api.spotify.com/v1/artists/0PykiHCcDsMPRV7s67qZ1B',
#     'id': '0PykiHCcDsMPRV7s67qZ1B',
#     'name': 'Tippu',
#     'type': 'artist',
#     'uri': 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 329013,
#   'explicit': False,
#   'external_ids': {'isrc': 'IND291600731'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/79B67CygqqtpaahPalGdgl'},
#   'href': 'https://api.spotify.com/v1/tracks/79B67CygqqtpaahPalGdgl',
#   'id': '79B67CygqqtpaahPalGdgl',
#   'is_local': False,
#   'name': 'Mudhal Mudhalai',
#   'popularity': 42,
#   'preview_url': 'https://p.scdn.co/mp3-preview/66bbd9fb169940330b6f284978d04c324d27667b?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:79B67CygqqtpaahPalGdgl'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NoJ7NuNs9nyj8Thoh1kbu'},
#      'href': 'https://api.spotify.com/v1/artists/2NoJ7NuNs9nyj8Thoh1kbu',
#      'id': '2NoJ7NuNs9nyj8Thoh1kbu',
#      'name': 'Hariharan',
#      'type': 'artist',
#      'uri': 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wPsNCwhEGb0KvChZ5DD52'},
#      'href': 'https://api.spotify.com/v1/artists/2wPsNCwhEGb0KvChZ5DD52',
#      'id': '2wPsNCwhEGb0KvChZ5DD52',
#      'name': 'K. J. Yesudas',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wPsNCwhEGb0KvChZ5DD52'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1kzbFZiILCf520UCCPOhvz'},
#    'href': 'https://api.spotify.com/v1/albums/1kzbFZiILCf520UCCPOhvz',
#    'id': '1kzbFZiILCf520UCCPOhvz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d6f63aefe2221a24e7043827',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d6f63aefe2221a24e7043827',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d6f63aefe2221a24e7043827',
#      'width': 64}],
#    'name': 'Singer Special Hariharan and K.J.Jesudas',
#    'release_date': '2013-05-13',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:1kzbFZiILCf520UCCPOhvz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NoJ7NuNs9nyj8Thoh1kbu'},
#     'href': 'https://api.spotify.com/v1/artists/2NoJ7NuNs9nyj8Thoh1kbu',
#     'id': '2NoJ7NuNs9nyj8Thoh1kbu',
#     'name': 'Hariharan',
#     'type': 'artist',
#     'uri': 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Yb0T3wUUNiIvHjqnfkbuH'},
#     'href': 'https://api.spotify.com/v1/artists/0Yb0T3wUUNiIvHjqnfkbuH',
#     'id': '0Yb0T3wUUNiIvHjqnfkbuH',
#     'name': 'Mahalakshmi Iyer',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Yb0T3wUUNiIvHjqnfkbuH'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 398341,
#   'explicit': False,
#   'external_ids': {'isrc': 'INF049900244'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/00QuXoF6LyKwH9xz7lXGdf'},
#   'href': 'https://api.spotify.com/v1/tracks/00QuXoF6LyKwH9xz7lXGdf',
#   'id': '00QuXoF6LyKwH9xz7lXGdf',
#   'is_local': False,
#   'name': 'Kurukku Siruthvalea (From Mudhalvan)',
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0113caa84116a413852a7fb9e10dd92443c33829?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:00QuXoF6LyKwH9xz7lXGdf'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3m49WVMU4zCkaVEKb8kFW7'},
#      'href': 'https://api.spotify.com/v1/artists/3m49WVMU4zCkaVEKb8kFW7',
#      'id': '3m49WVMU4zCkaVEKb8kFW7',
#      'name': 'Ilaiyaraaja',
#      'type': 'artist',
#      'uri': 'spotify:artist:3m49WVMU4zCkaVEKb8kFW7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6tzoyTXujURrI4cP3qddow'},
#    'href': 'https://api.spotify.com/v1/albums/6tzoyTXujURrI4cP3qddow',
#    'id': '6tzoyTXujURrI4cP3qddow',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736eb2962bda91af6ed29ee8ff',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026eb2962bda91af6ed29ee8ff',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516eb2962bda91af6ed29ee8ff',
#      'width': 64}],
#    'name': 'Neethaane En Ponvasantham (Original Motion Picture Soundtrack)',
#    'release_date': '2012-09-01',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:6tzoyTXujURrI4cP3qddow'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3m49WVMU4zCkaVEKb8kFW7'},
#     'href': 'https://api.spotify.com/v1/artists/3m49WVMU4zCkaVEKb8kFW7',
#     'id': '3m49WVMU4zCkaVEKb8kFW7',
#     'name': 'Ilaiyaraaja',
#     'type': 'artist',
#     'uri': 'spotify:artist:3m49WVMU4zCkaVEKb8kFW7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3eDT9fwXKuHWFvgZaaYC5v'},
#     'href': 'https://api.spotify.com/v1/artists/3eDT9fwXKuHWFvgZaaYC5v',
#     'id': '3eDT9fwXKuHWFvgZaaYC5v',
#     'name': 'Sunidhi Chauhan',
#     'type': 'artist',
#     'uri': 'spotify:artist:3eDT9fwXKuHWFvgZaaYC5v'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 235733,
#   'explicit': False,
#   'external_ids': {'isrc': 'INS171200447'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3re0HrBkLNV2lfHoTtSOgy'},
#   'href': 'https://api.spotify.com/v1/tracks/3re0HrBkLNV2lfHoTtSOgy',
#   'id': '3re0HrBkLNV2lfHoTtSOgy',
#   'is_local': False,
#   'name': 'Mudhal Murai',
#   'popularity': 47,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2bff6dfd6abbd5bd2ec46a7b4ae42041a84b998e?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3re0HrBkLNV2lfHoTtSOgy'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Xpg6PBSUOoho2lI9qLjiu'},
#      'href': 'https://api.spotify.com/v1/artists/5Xpg6PBSUOoho2lI9qLjiu',
#      'id': '5Xpg6PBSUOoho2lI9qLjiu',
#      'name': 'S. Janaki',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Xpg6PBSUOoho2lI9qLjiu'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4uV8s5nu0aGFhQZ43w2od9'},
#    'href': 'https://api.spotify.com/v1/albums/4uV8s5nu0aGFhQZ43w2od9',
#    'id': '4uV8s5nu0aGFhQZ43w2od9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27306c9223295ac72af0e132f25',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0206c9223295ac72af0e132f25',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485106c9223295ac72af0e132f25',
#      'width': 64}],
#    'name': 'Janaki Special',
#    'release_date': '2013-07-09',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:4uV8s5nu0aGFhQZ43w2od9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Xpg6PBSUOoho2lI9qLjiu'},
#     'href': 'https://api.spotify.com/v1/artists/5Xpg6PBSUOoho2lI9qLjiu',
#     'id': '5Xpg6PBSUOoho2lI9qLjiu',
#     'name': 'S. Janaki',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Xpg6PBSUOoho2lI9qLjiu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#     'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#     'id': '1SJOL9HJ08YOn92lFcYf8a',
#     'name': 'Shankar Mahadevan',
#     'type': 'artist',
#     'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 392045,
#   'explicit': False,
#   'external_ids': {'isrc': 'INF049900245'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3nhzRO4RPgq71kTlBah68A'},
#   'href': 'https://api.spotify.com/v1/tracks/3nhzRO4RPgq71kTlBah68A',
#   'id': '3nhzRO4RPgq71kTlBah68A',
#   'is_local': False,
#   'name': 'Mudhalvanae ( From "Mudhalvan")',
#   'popularity': 51,
#   'preview_url': 'https://p.scdn.co/mp3-preview/093f9122109a9db1a915be9723aa385757299aa9?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3nhzRO4RPgq71kTlBah68A'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#      'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#      'id': '1SJOL9HJ08YOn92lFcYf8a',
#      'name': 'Shankar Mahadevan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5t4ZtKPDT4r1ZPobRGIAyo'},
#    'href': 'https://api.spotify.com/v1/albums/5t4ZtKPDT4r1ZPobRGIAyo',
#    'id': '5t4ZtKPDT4r1ZPobRGIAyo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f52ac029b4974b9958fea06b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f52ac029b4974b9958fea06b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f52ac029b4974b9958fea06b',
#      'width': 64}],
#    'name': 'Hits of Shankar Mahadevan',
#    'release_date': '2013-05-29',
#    'release_date_precision': 'day',
#    'total_tracks': 26,
#    'type': 'album',
#    'uri': 'spotify:album:5t4ZtKPDT4r1ZPobRGIAyo'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SJOL9HJ08YOn92lFcYf8a'},
#     'href': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a',
#     'id': '1SJOL9HJ08YOn92lFcYf8a',
#     'name': 'Shankar Mahadevan',
#     'type': 'artist',
#     'uri': 'spotify:artist:1SJOL9HJ08YOn92lFcYf8a'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WPmTGeeoymoVlXVtsCwz7'},
#     'href': 'https://api.spotify.com/v1/artists/6WPmTGeeoymoVlXVtsCwz7',
#     'id': '6WPmTGeeoymoVlXVtsCwz7',
#     'name': 'Kavita Krishnamurthy',
#     'type': 'artist',
#     'uri': 'spotify:artist:6WPmTGeeoymoVlXVtsCwz7'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 334733,
#   'explicit': False,
#   'external_ids': {'isrc': 'INF049900246'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3qkoComBwdqR8ybOGo0jkw'},
#   'href': 'https://api.spotify.com/v1/tracks/3qkoComBwdqR8ybOGo0jkw',
#   'id': '3qkoComBwdqR8ybOGo0jkw',
#   'is_local': False,
#   'name': 'Uppu Karuvaadu ( From "Mudhalvan")',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8d105c14d68528b86756adac346f466e943972ff?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3qkoComBwdqR8ybOGo0jkw'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#      'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#      'id': '2ae6PxICSOZHvjqiCcgon8',
#      'name': 'S. P. Balasubrahmanyam',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wPsNCwhEGb0KvChZ5DD52'},
#      'href': 'https://api.spotify.com/v1/artists/2wPsNCwhEGb0KvChZ5DD52',
#      'id': '2wPsNCwhEGb0KvChZ5DD52',
#      'name': 'K. J. Yesudas',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wPsNCwhEGb0KvChZ5DD52'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2PtLTb5NE474dbmwT8d9nL'},
#    'href': 'https://api.spotify.com/v1/albums/2PtLTb5NE474dbmwT8d9nL',
#    'id': '2PtLTb5NE474dbmwT8d9nL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331aa5dd8aa2a5b9c0ab1d362',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231aa5dd8aa2a5b9c0ab1d362',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131aa5dd8aa2a5b9c0ab1d362',
#      'width': 64}],
#    'name': 'S.P.B and K.J.Jesudas Hits',
#    'release_date': '2013-05-10',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:2PtLTb5NE474dbmwT8d9nL'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#     'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#     'id': '2ae6PxICSOZHvjqiCcgon8',
#     'name': 'S. P. Balasubrahmanyam',
#     'type': 'artist',
#     'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/41BeeC5hYqvtGkM79RYvN4'},
#     'href': 'https://api.spotify.com/v1/artists/41BeeC5hYqvtGkM79RYvN4',
#     'id': '41BeeC5hYqvtGkM79RYvN4',
#     'name': 'Harini',
#     'type': 'artist',
#     'uri': 'spotify:artist:41BeeC5hYqvtGkM79RYvN4'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 367203,
#   'explicit': False,
#   'external_ids': {'isrc': 'INF049900247'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6GBn7HwE7SBqVKzdCPeheI'},
#   'href': 'https://api.spotify.com/v1/tracks/6GBn7HwE7SBqVKzdCPeheI',
#   'id': '6GBn7HwE7SBqVKzdCPeheI',
#   'is_local': False,
#   'name': 'Azhagana Rakshasiyea (From Mudhalvan)',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/341115a2a4d521bbe5696fbd2f374ddf7beda545?cid=3f171623fda2487bb16422c30f7983e6',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:6GBn7HwE7SBqVKzdCPeheI'}]

# %%
items_in_tracks = results['tracks']['items']
if len(items_in_tracks) > 0:
    for item in items_in_tracks:
        print(item['name'] + " - By - " + item['artists'][0]['name'])
        print("Track ID: " + item['id'] + " / Artist ID - " + item['artists'][0]['id'])
        print("------")
# Out:
# Mudhal Nee Mudivum Nee Title Track - By - Darbuka Siva
# Track ID: 4oNVmnywnXguyk76wkMuIb / Artist ID - 5t97rjifUl8d4HNwSzbCv9
# ------
# Paartha Mudhal - By - Harris Jayaraj
# Track ID: 03GldviaGI7cvpCBuuyrrP / Artist ID - 29aw5YCdIw2FEXYyAJZI8l
# ------
# Mudhal Nee Mudivum Nee Title Track (From "Mudhal Nee Mudivum Nee") - By - Darbuka Siva
# Track ID: 1AzNN19lPYC68iacrbWL8X / Artist ID - 5t97rjifUl8d4HNwSzbCv9
# ------
# Merke Merke ( From" Kanda Naal Mudhalai") - By - Shankar Mahadevan
# Track ID: 1DfsxoKqz6M6CSOkX8HpxR / Artist ID - 1SJOL9HJ08YOn92lFcYf8a
# ------
# Mudhal Mudhalai - By - Harris Jayaraj
# Track ID: 79B67CygqqtpaahPalGdgl / Artist ID - 29aw5YCdIw2FEXYyAJZI8l
# ------
# Kurukku Siruthvalea (From Mudhalvan) - By - Hariharan
# Track ID: 00QuXoF6LyKwH9xz7lXGdf / Artist ID - 2NoJ7NuNs9nyj8Thoh1kbu
# ------
# Mudhal Murai - By - Ilaiyaraaja
# Track ID: 3re0HrBkLNV2lfHoTtSOgy / Artist ID - 3m49WVMU4zCkaVEKb8kFW7
# ------
# Mudhalvanae ( From "Mudhalvan") - By - S. Janaki
# Track ID: 3nhzRO4RPgq71kTlBah68A / Artist ID - 5Xpg6PBSUOoho2lI9qLjiu
# ------
# Uppu Karuvaadu ( From "Mudhalvan") - By - Shankar Mahadevan
# Track ID: 3qkoComBwdqR8ybOGo0jkw / Artist ID - 1SJOL9HJ08YOn92lFcYf8a
# ------
# Azhagana Rakshasiyea (From Mudhalvan) - By - S. P. Balasubrahmanyam
# Track ID: 6GBn7HwE7SBqVKzdCPeheI / Artist ID - 2ae6PxICSOZHvjqiCcgon8
# ------

# %%
song_id = '4oNVmnywnXguyk76wkMuIb'

# %% [markdown]
# ## Generating token for recommendation

# %%
import requests
import base64

# %%
def get_token(clientId,clientSecret):
    url = "https://accounts.spotify.com/api/token"
    headers = {}
    data = {}
    message = f"{clientId}:{clientSecret}"
    messageBytes = message.encode('ascii')
    base64Bytes = base64.b64encode(messageBytes)
    base64Message = base64Bytes.decode('ascii')
    headers['Authorization'] = "Basic " + base64Message
    data['grant_type'] = "client_credentials"
    r = requests.post(url, headers=headers, data=data)
    token = r.json()['access_token']
    return token

# %%
token = get_token(Spotify_Client_ID, Spotify_Client_Secret)

# %%
token
# Out:
# 'BQCf4_Dq9Ly_yiOaa81VxtrB-G1QuGoYepb4REgtl7eoComx-UUpkHzVbvhQpe3_9gAJe-TsFRvHVTHvJ0P4FacTiuEhjJFabZq66v5wMOYArBCmRIA'

# %% [markdown]
# ## Track based recommendations

# %%
import requests
import random
import pandas as pd
import matplotlib.pyplot as plt

def get_track_recommendations(seed_tracks, token, genres=None, target_popularity=random.randint(1,50)):
    limit = 10
    recUrl = f"https://api.spotify.com/v1/recommendations?limit={limit}&seed_tracks={seed_tracks}"
    
    if genres:
        recUrl += f"&seed_genres={','.join(genres)}"
    
    recUrl += f"&target_popularity={target_popularity}"

    headers = {
        "Authorization": "Bearer " + token
    }

    res = requests.get(url=recUrl, headers=headers)
    if res.status_code != 200:
        raise Exception(f"Spotify API Error: {res.json()}")
    return res.json()

# %%
# Example usage with expanded genre selection and lower popularity target
genres = ['hip-hop', 'classical', 'k-pop', 'latin', 'indie']
json_response = get_track_recommendations(song_id, token)

# %%
json_response
# Out:
# {'tracks': [{'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15ClyGUe5g2vllncIC4tp6'},
#       'href': 'https://api.spotify.com/v1/artists/15ClyGUe5g2vllncIC4tp6',
#       'id': '15ClyGUe5g2vllncIC4tp6',
#       'name': 'Pradeep Kumar',
#       'type': 'artist',
#       'uri': 'spotify:artist:15ClyGUe5g2vllncIC4tp6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwNmkTnRKkILlrPV2yPpC'},
#       'href': 'https://api.spotify.com/v1/artists/1ZwNmkTnRKkILlrPV2yPpC',
#       'id': '1ZwNmkTnRKkILlrPV2yPpC',
#       'name': 'Susha',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZwNmkTnRKkILlrPV2yPpC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HTHaSRTYE7rVuFJD9ADSi'},
#     'href': 'https://api.spotify.com/v1/albums/3HTHaSRTYE7rVuFJD9ADSi',
#     'id': '3HTHaSRTYE7rVuFJD9ADSi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737000d0fcb04c37967633e4b1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027000d0fcb04c37967633e4b1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517000d0fcb04c37967633e4b1',
#       'width': 64}],
#     'name': 'Yodhakaa',
#     'release_date': '2011-12-10',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3HTHaSRTYE7rVuFJD9ADSi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15ClyGUe5g2vllncIC4tp6'},
#      'href': 'https://api.spotify.com/v1/artists/15ClyGUe5g2vllncIC4tp6',
#      'id': '15ClyGUe5g2vllncIC4tp6',
#      'name': 'Pradeep Kumar',
#      'type': 'artist',
#      'uri': 'spotify:artist:15ClyGUe5g2vllncIC4tp6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwNmkTnRKkILlrPV2yPpC'},
#      'href': 'https://api.spotify.com/v1/artists/1ZwNmkTnRKkILlrPV2yPpC',
#      'id': '1ZwNmkTnRKkILlrPV2yPpC',
#      'name': 'Susha',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZwNmkTnRKkILlrPV2yPpC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 285466,
#    'explicit': False,
#    'external_ids': {'isrc': 'INT201000186'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0wagWCkOCtPbSvvtstkCQt'},
#    'href': 'https://api.spotify.com/v1/tracks/0wagWCkOCtPbSvvtstkCQt',
#    'id': '0wagWCkOCtPbSvvtstkCQt',
#    'is_local': False,
#    'name': 'Shri Hari Vallabhe',
#    'popularity': 7,
#    'preview_url': 'https://p.scdn.co/mp3-preview/506eed7e98f81bc54598c06bd2e871f59b59344f?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0wagWCkOCtPbSvvtstkCQt'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3hVMIzKCAel4KOC39IZ6HD'},
#     'href': 'https://api.spotify.com/v1/albums/3hVMIzKCAel4KOC39IZ6HD',
#     'id': '3hVMIzKCAel4KOC39IZ6HD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732ba620df6d789729ba5de023',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022ba620df6d789729ba5de023',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512ba620df6d789729ba5de023',
#       'width': 64}],
#     'name': 'Travelers: Dosti Music Project',
#     'release_date': '2017-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3hVMIzKCAel4KOC39IZ6HD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/141Pg3rz3OymtpbTPfo8RK'},
#      'href': 'https://api.spotify.com/v1/artists/141Pg3rz3OymtpbTPfo8RK',
#      'id': '141Pg3rz3OymtpbTPfo8RK',
#      'name': 'Abakis',
#      'type': 'artist',
#      'uri': 'spotify:artist:141Pg3rz3OymtpbTPfo8RK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/57TBZaW7CoYNMyGYnfbS9E'},
#      'href': 'https://api.spotify.com/v1/artists/57TBZaW7CoYNMyGYnfbS9E',
#      'id': '57TBZaW7CoYNMyGYnfbS9E',
#      'name': 'Danish Khawaja',
#      'type': 'artist',
#      'uri': 'spotify:artist:57TBZaW7CoYNMyGYnfbS9E'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aEd1lnX8fEdyUJov32PlE'},
#      'href': 'https://api.spotify.com/v1/artists/7aEd1lnX8fEdyUJov32PlE',
#      'id': '7aEd1lnX8fEdyUJov32PlE',
#      'name': 'Debasmita Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:7aEd1lnX8fEdyUJov32PlE'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 193960,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ7GP1701011'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Lq62hLaOQdNTjsBdLkCP1'},
#    'href': 'https://api.spotify.com/v1/tracks/6Lq62hLaOQdNTjsBdLkCP1',
#    'id': '6Lq62hLaOQdNTjsBdLkCP1',
#    'is_local': False,
#    'name': 'Here I Am',
#    'popularity': 7,
#    'preview_url': 'https://p.scdn.co/mp3-preview/27ec47a795c8ca2b6e4ddeee2801cd262d12df66?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:6Lq62hLaOQdNTjsBdLkCP1'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3S6mjJEnQfisWdm0DgujZ3'},
#     'href': 'https://api.spotify.com/v1/albums/3S6mjJEnQfisWdm0DgujZ3',
#     'id': '3S6mjJEnQfisWdm0DgujZ3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273933c9286a6ba94d90a826169',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02933c9286a6ba94d90a826169',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851933c9286a6ba94d90a826169',
#       'width': 64}],
#     'name': 'Mudhal Nee Mudivum Nee (Original Background Score)',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 34,
#     'type': 'album',
#     'uri': 'spotify:album:3S6mjJEnQfisWdm0DgujZ3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 60000,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172201299'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0XXRuhP2Q1IjooFCmxfZAr'},
#    'href': 'https://api.spotify.com/v1/tracks/0XXRuhP2Q1IjooFCmxfZAr',
#    'id': '0XXRuhP2Q1IjooFCmxfZAr',
#    'is_local': False,
#    'name': "Valentine's Day - Background Score",
#    'popularity': 5,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0599a5764ba5356562de4d97d0aafa6a40ff5c84?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:0XXRuhP2Q1IjooFCmxfZAr'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uRhRME6wArdeaQ2s26Q0A'},
#       'href': 'https://api.spotify.com/v1/artists/3uRhRME6wArdeaQ2s26Q0A',
#       'id': '3uRhRME6wArdeaQ2s26Q0A',
#       'name': 'James Thakara',
#       'type': 'artist',
#       'uri': 'spotify:artist:3uRhRME6wArdeaQ2s26Q0A'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dDSQfbUWrNvRqpNP92slb'},
#       'href': 'https://api.spotify.com/v1/artists/7dDSQfbUWrNvRqpNP92slb',
#       'id': '7dDSQfbUWrNvRqpNP92slb',
#       'name': 'Kaber Vasuki',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dDSQfbUWrNvRqpNP92slb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7xi7gSJr5Yk7eqJKUcCJ6L'},
#     'href': 'https://api.spotify.com/v1/albums/7xi7gSJr5Yk7eqJKUcCJ6L',
#     'id': '7xi7gSJr5Yk7eqJKUcCJ6L',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c5c50357cd5aec327df3b271',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c5c50357cd5aec327df3b271',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c5c50357cd5aec327df3b271',
#       'width': 64}],
#     'name': 'Vanma Padhaiyil (From "Rocky")',
#     'release_date': '2021-12-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7xi7gSJr5Yk7eqJKUcCJ6L'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uRhRME6wArdeaQ2s26Q0A'},
#      'href': 'https://api.spotify.com/v1/artists/3uRhRME6wArdeaQ2s26Q0A',
#      'id': '3uRhRME6wArdeaQ2s26Q0A',
#      'name': 'James Thakara',
#      'type': 'artist',
#      'uri': 'spotify:artist:3uRhRME6wArdeaQ2s26Q0A'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7dDSQfbUWrNvRqpNP92slb'},
#      'href': 'https://api.spotify.com/v1/artists/7dDSQfbUWrNvRqpNP92slb',
#      'id': '7dDSQfbUWrNvRqpNP92slb',
#      'name': 'Kaber Vasuki',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dDSQfbUWrNvRqpNP92slb'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 290175,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182116155'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6LPl6a7PGYhUL9hRboPXeh'},
#    'href': 'https://api.spotify.com/v1/tracks/6LPl6a7PGYhUL9hRboPXeh',
#    'id': '6LPl6a7PGYhUL9hRboPXeh',
#    'is_local': False,
#    'name': 'Vanma Padhaiyil (From "Rocky")',
#    'popularity': 1,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6LPl6a7PGYhUL9hRboPXeh'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BWGWW865iPYzyM5PTsKGM'},
#       'href': 'https://api.spotify.com/v1/artists/4BWGWW865iPYzyM5PTsKGM',
#       'id': '4BWGWW865iPYzyM5PTsKGM',
#       'name': 'Harihara Sudhan',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BWGWW865iPYzyM5PTsKGM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/42e246PXlPrctkKRO8QJ3d'},
#     'href': 'https://api.spotify.com/v1/albums/42e246PXlPrctkKRO8QJ3d',
#     'id': '42e246PXlPrctkKRO8QJ3d',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273990a3d3ec0893272fc4c71d6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02990a3d3ec0893272fc4c71d6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851990a3d3ec0893272fc4c71d6',
#       'width': 64}],
#     'name': 'Orey Oru Oorile (From "Rocky")',
#     'release_date': '2021-12-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:42e246PXlPrctkKRO8QJ3d'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BWGWW865iPYzyM5PTsKGM'},
#      'href': 'https://api.spotify.com/v1/artists/4BWGWW865iPYzyM5PTsKGM',
#      'id': '4BWGWW865iPYzyM5PTsKGM',
#      'name': 'Harihara Sudhan',
#      'type': 'artist',
#      'uri': 'spotify:artist:4BWGWW865iPYzyM5PTsKGM'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 267029,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182116255'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/65WP9BxbAcxzqxQhxpHu4Y'},
#    'href': 'https://api.spotify.com/v1/tracks/65WP9BxbAcxzqxQhxpHu4Y',
#    'id': '65WP9BxbAcxzqxQhxpHu4Y',
#    'is_local': False,
#    'name': 'Orey Oru Oorile (From "Rocky")',
#    'popularity': 1,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:65WP9BxbAcxzqxQhxpHu4Y'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZuH4DLbLlebsgACbCe392'},
#       'href': 'https://api.spotify.com/v1/artists/6ZuH4DLbLlebsgACbCe392',
#       'id': '6ZuH4DLbLlebsgACbCe392',
#       'name': 'G. Anthony',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZuH4DLbLlebsgACbCe392'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/24OYFfSFteT3xfiWo9sgHJ'},
#     'href': 'https://api.spotify.com/v1/albums/24OYFfSFteT3xfiWo9sgHJ',
#     'id': '24OYFfSFteT3xfiWo9sgHJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736134bef2ac1450b87a95b0a8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026134bef2ac1450b87a95b0a8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516134bef2ac1450b87a95b0a8',
#       'width': 64}],
#     'name': 'Naan Sinam Ariven (From "Rocky")',
#     'release_date': '2020-03-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:24OYFfSFteT3xfiWo9sgHJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZuH4DLbLlebsgACbCe392'},
#      'href': 'https://api.spotify.com/v1/artists/6ZuH4DLbLlebsgACbCe392',
#      'id': '6ZuH4DLbLlebsgACbCe392',
#      'name': 'G. Anthony',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ZuH4DLbLlebsgACbCe392'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 287893,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS182000619'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2yvYzEtCnP5gbGu0aiao4I'},
#    'href': 'https://api.spotify.com/v1/tracks/2yvYzEtCnP5gbGu0aiao4I',
#    'id': '2yvYzEtCnP5gbGu0aiao4I',
#    'is_local': False,
#    'name': 'Naan Sinam Ariven (From "Rocky")',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2yvYzEtCnP5gbGu0aiao4I'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15ClyGUe5g2vllncIC4tp6'},
#       'href': 'https://api.spotify.com/v1/artists/15ClyGUe5g2vllncIC4tp6',
#       'id': '15ClyGUe5g2vllncIC4tp6',
#       'name': 'Pradeep Kumar',
#       'type': 'artist',
#       'uri': 'spotify:artist:15ClyGUe5g2vllncIC4tp6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwNmkTnRKkILlrPV2yPpC'},
#       'href': 'https://api.spotify.com/v1/artists/1ZwNmkTnRKkILlrPV2yPpC',
#       'id': '1ZwNmkTnRKkILlrPV2yPpC',
#       'name': 'Susha',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZwNmkTnRKkILlrPV2yPpC'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HTHaSRTYE7rVuFJD9ADSi'},
#     'href': 'https://api.spotify.com/v1/albums/3HTHaSRTYE7rVuFJD9ADSi',
#     'id': '3HTHaSRTYE7rVuFJD9ADSi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737000d0fcb04c37967633e4b1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027000d0fcb04c37967633e4b1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517000d0fcb04c37967633e4b1',
#       'width': 64}],
#     'name': 'Yodhakaa',
#     'release_date': '2011-12-10',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3HTHaSRTYE7rVuFJD9ADSi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/15ClyGUe5g2vllncIC4tp6'},
#      'href': 'https://api.spotify.com/v1/artists/15ClyGUe5g2vllncIC4tp6',
#      'id': '15ClyGUe5g2vllncIC4tp6',
#      'name': 'Pradeep Kumar',
#      'type': 'artist',
#      'uri': 'spotify:artist:15ClyGUe5g2vllncIC4tp6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZwNmkTnRKkILlrPV2yPpC'},
#      'href': 'https://api.spotify.com/v1/artists/1ZwNmkTnRKkILlrPV2yPpC',
#      'id': '1ZwNmkTnRKkILlrPV2yPpC',
#      'name': 'Susha',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZwNmkTnRKkILlrPV2yPpC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 284066,
#    'explicit': False,
#    'external_ids': {'isrc': 'INT201000190'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5GIV2HywTFCTcq4OurRSLz'},
#    'href': 'https://api.spotify.com/v1/tracks/5GIV2HywTFCTcq4OurRSLz',
#    'id': '5GIV2HywTFCTcq4OurRSLz',
#    'is_local': False,
#    'name': 'Shwetaambara',
#    'popularity': 6,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1aede4cc6dc663df36dad971a1c58f4b6e5c0d91?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5GIV2HywTFCTcq4OurRSLz'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3hVMIzKCAel4KOC39IZ6HD'},
#     'href': 'https://api.spotify.com/v1/albums/3hVMIzKCAel4KOC39IZ6HD',
#     'id': '3hVMIzKCAel4KOC39IZ6HD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732ba620df6d789729ba5de023',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022ba620df6d789729ba5de023',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512ba620df6d789729ba5de023',
#       'width': 64}],
#     'name': 'Travelers: Dosti Music Project',
#     'release_date': '2017-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3hVMIzKCAel4KOC39IZ6HD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6axiqgCSTRUW0RJ4J8lO54'},
#      'href': 'https://api.spotify.com/v1/artists/6axiqgCSTRUW0RJ4J8lO54',
#      'id': '6axiqgCSTRUW0RJ4J8lO54',
#      'name': 'Slowspin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6axiqgCSTRUW0RJ4J8lO54'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/57TBZaW7CoYNMyGYnfbS9E'},
#      'href': 'https://api.spotify.com/v1/artists/57TBZaW7CoYNMyGYnfbS9E',
#      'id': '57TBZaW7CoYNMyGYnfbS9E',
#      'name': 'Danish Khawaja',
#      'type': 'artist',
#      'uri': 'spotify:artist:57TBZaW7CoYNMyGYnfbS9E'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aEd1lnX8fEdyUJov32PlE'},
#      'href': 'https://api.spotify.com/v1/artists/7aEd1lnX8fEdyUJov32PlE',
#      'id': '7aEd1lnX8fEdyUJov32PlE',
#      'name': 'Debasmita Bhattacharya',
#      'type': 'artist',
#      'uri': 'spotify:artist:7aEd1lnX8fEdyUJov32PlE'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 205120,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ7GP1701007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4C5cdwIOwotw3aEgChTfcc'},
#    'href': 'https://api.spotify.com/v1/tracks/4C5cdwIOwotw3aEgChTfcc',
#    'id': '4C5cdwIOwotw3aEgChTfcc',
#    'is_local': False,
#    'name': 'Patience',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/abcc135449a6800e40d1eccfe39eee34e19cc435?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:4C5cdwIOwotw3aEgChTfcc'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#       'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#       'id': '5t97rjifUl8d4HNwSzbCv9',
#       'name': 'Darbuka Siva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3S6mjJEnQfisWdm0DgujZ3'},
#     'href': 'https://api.spotify.com/v1/albums/3S6mjJEnQfisWdm0DgujZ3',
#     'id': '3S6mjJEnQfisWdm0DgujZ3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273933c9286a6ba94d90a826169',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02933c9286a6ba94d90a826169',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851933c9286a6ba94d90a826169',
#       'width': 64}],
#     'name': 'Mudhal Nee Mudivum Nee (Original Background Score)',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 34,
#     'type': 'album',
#     'uri': 'spotify:album:3S6mjJEnQfisWdm0DgujZ3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t97rjifUl8d4HNwSzbCv9'},
#      'href': 'https://api.spotify.com/v1/artists/5t97rjifUl8d4HNwSzbCv9',
#      'id': '5t97rjifUl8d4HNwSzbCv9',
#      'name': 'Darbuka Siva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t97rjifUl8d4HNwSzbCv9'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 60000,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS172201297'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7lrJj5kE43ujur3D7KPYUw'},
#    'href': 'https://api.spotify.com/v1/tracks/7lrJj5kE43ujur3D7KPYUw',
#    'id': '7lrJj5kE43ujur3D7KPYUw',
#    'is_local': False,
#    'name': 'Acid Test - Background Score',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e3b49a4f884b2eccd1a3b541719f2744f6fe8ccf?cid=3f171623fda2487bb16422c30f7983e6',
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:7lrJj5kE43ujur3D7KPYUw'},
#   {'album': {'album_type': 'COMPILATION',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#       'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#       'id': '2ae6PxICSOZHvjqiCcgon8',
#       'name': 'S. P. Balasubrahmanyam',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1jMahmIsXlq2SsMIi496oM'},
#     'href': 'https://api.spotify.com/v1/albums/1jMahmIsXlq2SsMIi496oM',
#     'id': '1jMahmIsXlq2SsMIi496oM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fb5b53707e233dde56e68250',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fb5b53707e233dde56e68250',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fb5b53707e233dde56e68250',
#       'width': 64}],
#     'name': 'S.P. Balasubrahmanyam All Time Hits',
#     'release_date': '2021-06-03',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1jMahmIsXlq2SsMIi496oM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#      'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#      'id': '2ae6PxICSOZHvjqiCcgon8',
#      'name': 'S. P. Balasubrahmanyam',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/70B80Lwx2sxti0M1Ng9e8K'},
#      'href': 'https://api.spotify.com/v1/artists/70B80Lwx2sxti0M1Ng9e8K',
#      'id': '70B80Lwx2sxti0M1Ng9e8K',
#      'name': 'Udit Narayan',
#      'type': 'artist',
#      'uri': 'spotify:artist:70B80Lwx2sxti0M1Ng9e8K'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/31zE3XsSq1gHAik8uajDFP'},
#      'href': 'https://api.spotify.com/v1/artists/31zE3XsSq1gHAik8uajDFP',
#      'id': '31zE3XsSq1gHAik8uajDFP',
#      'name': 'S.P. Pallavi',
#      'type': 'artist',
#      'uri': 'spotify:artist:31zE3XsSq1gHAik8uajDFP'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 289306,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS181423219'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4wZHDf2qi0q9oZDaEsmStn'},
#    'href': 'https://api.spotify.com/v1/tracks/4wZHDf2qi0q9oZDaEsmStn',
#    'id': '4wZHDf2qi0q9oZDaEsmStn',
#    'is_local': False,
#    'name': 'Kathalikkum Penin Kaikal (From "Kaadhalan")',
#    'popularity': 26,
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4wZHDf2qi0q9oZDaEsmStn'}],
#  'seeds': [{'initialPoolSize': 500,
#    'afterFilteringSize': 500,
#    'afterRelinkingSize': 500,
#    'id': '4oNVmnywnXguyk76wkMuIb',
#    'type': 'TRACK',
#    'href': 'https://api.spotify.com/v1/tracks/4oNVmnywnXguyk76wkMuIb'}]}

# %%
uris =[]
for i in json_response['tracks']:
    uris.append(i)
    print(f"\"{i['name']}\" by({i['artists'][0]['name']})")
# Out:
# "Shri Hari Vallabhe" by(Pradeep Kumar)
# "Here I Am" by(Abakis)
# "Valentine's Day - Background Score" by(Darbuka Siva)
# "Vanma Padhaiyil (From "Rocky")" by(James Thakara)
# "Orey Oru Oorile (From "Rocky")" by(Harihara Sudhan)
# "Naan Sinam Ariven (From "Rocky")" by(G. Anthony)
# "Shwetaambara" by(Pradeep Kumar)
# "Patience" by(Slowspin)
# "Acid Test - Background Score" by(Darbuka Siva)
# "Kathalikkum Penin Kaikal (From "Kaadhalan")" by(S. P. Balasubrahmanyam)

# %%
recolist = json_response['tracks']
print(len(recolist))
# Out:
# 10

# %%
recommendation_result = pd.DataFrame(recolist)
recommendation_result
# Out:
#                                                album  \
# 0  {'album_type': 'COMPILATION', 'artists': [{'ex...
# 1  {'album_type': 'COMPILATION', 'artists': [{'ex...
# 2  {'album_type': 'ALBUM', 'artists': [{'external...
# 3  {'album_type': 'SINGLE', 'artists': [{'externa...
# 4  {'album_type': 'SINGLE', 'artists': [{'externa...
# 5  {'album_type': 'SINGLE', 'artists': [{'externa...
# 6  {'album_type': 'COMPILATION', 'artists': [{'ex...
# 7  {'album_type': 'COMPILATION', 'artists': [{'ex...
# 8  {'album_type': 'ALBUM', 'artists': [{'external...
# 9  {'album_type': 'COMPILATION', 'artists': [{'ex...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
# 5  [{'external_urls': {'spotify': 'https://open.s...
# 6  [{'external_urls': {'spotify': 'https://open.s...
# 7  [{'external_urls': {'spotify': 'https://open.s...
# 8  [{'external_urls': {'spotify': 'https://open.s...
# 9  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3                                                 []            1
# 4                                                 []            1
# 5                                                 []            1
# 6  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 7  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 8  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 9                                                 []            1
#
#    duration_ms  explicit              external_ids  \
# 0       285466     False  {'isrc': 'INT201000186'}
# 1       193960     False  {'isrc': 'QZ7GP1701011'}
# 2        60000     False  {'isrc': 'INS172201299'}
# 3       290175     False  {'isrc': 'INS182116155'}
# 4       267029     False  {'isrc': 'INS182116255'}
# 5       287893     False  {'isrc': 'INS182000619'}
# 6       284066     False  {'isrc': 'INT201000190'}
# 7       205120     False  {'isrc': 'QZ7GP1701007'}
# 8        60000     False  {'isrc': 'INS172201297'}
# 9       289306     False  {'isrc': 'INS181423219'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/0w...
# 1  {'spotify': 'https://open.spotify.com/track/6L...
# 2  {'spotify': 'https://open.spotify.com/track/0X...
# 3  {'spotify': 'https://open.spotify.com/track/6L...
# 4  {'spotify': 'https://open.spotify.com/track/65...
# 5  {'spotify': 'https://open.spotify.com/track/2y...
# 6  {'spotify': 'https://open.spotify.com/track/5G...
# 7  {'spotify': 'https://open.spotify.com/track/4C...
# 8  {'spotify': 'https://open.spotify.com/track/7l...
# 9  {'spotify': 'https://open.spotify.com/track/4w...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/0wagWCkOCtPb...  0wagWCkOCtPbSvvtstkCQt
# 1  https://api.spotify.com/v1/tracks/6Lq62hLaOQdN...  6Lq62hLaOQdNTjsBdLkCP1
# 2  https://api.spotify.com/v1/tracks/0XXRuhP2Q1Ij...  0XXRuhP2Q1IjooFCmxfZAr
# 3  https://api.spotify.com/v1/tracks/6LPl6a7PGYhU...  6LPl6a7PGYhUL9hRboPXeh
# 4  https://api.spotify.com/v1/tracks/65WP9BxbAcxz...  65WP9BxbAcxzqxQhxpHu4Y
# 5  https://api.spotify.com/v1/tracks/2yvYzEtCnP5g...  2yvYzEtCnP5gbGu0aiao4I
# 6  https://api.spotify.com/v1/tracks/5GIV2HywTFCT...  5GIV2HywTFCTcq4OurRSLz
# 7  https://api.spotify.com/v1/tracks/4C5cdwIOwotw...  4C5cdwIOwotw3aEgChTfcc
# 8  https://api.spotify.com/v1/tracks/7lrJj5kE43uj...  7lrJj5kE43ujur3D7KPYUw
# 9  https://api.spotify.com/v1/tracks/4wZHDf2qi0q9...  4wZHDf2qi0q9oZDaEsmStn
#
#    is_local                                         name  popularity  \
# 0     False                           Shri Hari Vallabhe           7
# 1     False                                    Here I Am           7
# 2     False           Valentine's Day - Background Score           5
# 3     False               Vanma Padhaiyil (From "Rocky")           1
# 4     False               Orey Oru Oorile (From "Rocky")           1
# 5     False             Naan Sinam Ariven (From "Rocky")           0
# 6     False                                 Shwetaambara           6
# 7     False                                     Patience           2
# 8     False                 Acid Test - Background Score           1
# 9     False  Kathalikkum Penin Kaikal (From "Kaadhalan")          26
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/506eed7e98f81bc5...             1  track
# 1  https://p.scdn.co/mp3-preview/27ec47a795c8ca2b...            11  track
# 2  https://p.scdn.co/mp3-preview/0599a5764ba53565...            15  track
# 3                                               None             1  track
# 4                                               None             1  track
# 5                                               None             1  track
# 6  https://p.scdn.co/mp3-preview/1aede4cc6dc663df...             5  track
# 7  https://p.scdn.co/mp3-preview/abcc135449a6800e...             7  track
# 8  https://p.scdn.co/mp3-preview/e3b49a4f884b2ecc...            14  track
# 9                                               None             3  track
#
#                                     uri
# 0  spotify:track:0wagWCkOCtPbSvvtstkCQt
# 1  spotify:track:6Lq62hLaOQdNTjsBdLkCP1
# 2  spotify:track:0XXRuhP2Q1IjooFCmxfZAr
# 3  spotify:track:6LPl6a7PGYhUL9hRboPXeh
# 4  spotify:track:65WP9BxbAcxzqxQhxpHu4Y
# 5  spotify:track:2yvYzEtCnP5gbGu0aiao4I
# 6  spotify:track:5GIV2HywTFCTcq4OurRSLz
# 7  spotify:track:4C5cdwIOwotw3aEgChTfcc
# 8  spotify:track:7lrJj5kE43ujur3D7KPYUw
# 9  spotify:track:4wZHDf2qi0q9oZDaEsmStn

# %%
reco_df = recommendation_result[['name', 'explicit', 'duration_ms', 'popularity']]
reco_df
# Out:
#                                           name  explicit  duration_ms  \
# 0                           Shri Hari Vallabhe     False       285466
# 1                                    Here I Am     False       193960
# 2           Valentine's Day - Background Score     False        60000
# 3               Vanma Padhaiyil (From "Rocky")     False       290175
# 4               Orey Oru Oorile (From "Rocky")     False       267029
# 5             Naan Sinam Ariven (From "Rocky")     False       287893
# 6                                 Shwetaambara     False       284066
# 7                                     Patience     False       205120
# 8                 Acid Test - Background Score     False        60000
# 9  Kathalikkum Penin Kaikal (From "Kaadhalan")     False       289306
#
#    popularity
# 0           7
# 1           7
# 2           5
# 3           1
# 4           1
# 5           0
# 6           6
# 7           2
# 8           1
# 9          26

# %%
# Simple Data Visualization
plt.figure(figsize=(10, 6))
plt.scatter(reco_df['name'], reco_df['popularity'], alpha=0.7)
plt.xlabel('Track Name')
plt.ylabel('Popularity')
plt.title('Popularity of Recommended Tracks')
plt.xticks(rotation=45)
plt.show()

# %%
# Simple User Feedback Mechanism
def get_user_feedback(recommendations):
    feedback = {}
    for track in recommendations:
        track_name = track['name']
        artist_name = track['artists'][0]['name']
        print(f"Rate '{track_name}' by {artist_name} (1-5): ", end='')
        rating = input()
        feedback[track_name] = int(rating)
    return feedback
